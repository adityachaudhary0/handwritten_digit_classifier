# %%
from tensorflow.keras.datasets import mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()

print(X_train.shape)  # (60000, 28, 28)
print(y_train.shape)  # (60000,)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# (60000, 28, 28)
# (60000,)

# %%
import matplotlib.pyplot as plt

plt.imshow(X_test[1], cmap='gray')
plt.title(f"Label: {y_test[1]}")
plt.axis('off')
plt.show()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten

model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.fit(X_train, y_train, epochs=100, validation_split=0.2,callbacks=[early_stop])
# Out:
# Epoch 1/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8035 - loss: 8.3200 - val_accuracy: 0.8760 - val_loss: 0.5439
# Epoch 2/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8923 - loss: 0.4759 - val_accuracy: 0.9133 - val_loss: 0.3757
# Epoch 3/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9209 - loss: 0.3199 - val_accuracy: 0.9256 - val_loss: 0.3317
# Epoch 4/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9312 - loss: 0.2760 - val_accuracy: 0.9342 - val_loss: 0.2823
# Epoch 5/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9371 - loss: 0.2453 - val_accuracy: 0.9342 - val_loss: 0.3077
# Epoch 6/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9444 - loss: 0.2169 - val_accuracy: 0.9332 - val_loss: 0.2841
# Epoch 7/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9477 - loss: 0.2022 - val_accuracy: 0.9474 - val_loss: 0.2391
# Epoch 8/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9498 - loss: 0.2065 - val_accuracy: 0.9408 - val_loss: 0.2798
# Epoch 9/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9533 - loss: 0.1852 - val_accuracy: 0.9433 - val_loss: 0.2610
# Epoch 10/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9561 - loss: 0.1748 - val_accuracy: 0.9357 - val_loss: 0.2636
# Epoch 11/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9593 - loss: 0.1581 - val_accuracy: 0.9463 - val_loss: 0.2708
# Epoch 12/100
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9597 - loss: 0.1694 - val_accuracy: 0.9452 - val_loss: 0.2766

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print("Test accuracy:", test_accuracy)
print("Test loss:", test_loss)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9437 - loss: 0.2845
# Test accuracy: 0.9491999745368958
# Test loss: 0.25279295444488525

# %%
import numpy as np

y_pred_probs = model.predict(X_test)      # probabilities
y_pred = np.argmax(y_pred_probs, axis=1)  # final predicted class
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
import matplotlib.pyplot as plt

for i in range(5):
    plt.imshow(X_test[i], cmap='gray')
    plt.title(f"True: {y_test[i]} | Pred: {y_pred[i]}")
    plt.axis('off')
    plt.show()

# %%
# !git init
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/.git/

# %%
# !git checkout -b main
# Out:
# Switched to a new branch 'main'

# %%
# !git add .

# %%
# !git commit -m "01"
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@685f61287ef3.(none)')
